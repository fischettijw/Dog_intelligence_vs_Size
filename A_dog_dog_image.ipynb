# %% [markdown]
# [Display Image from File](https://www.youtube.com/watch?v=WH5y0ZPP5lY&t=11s)
#
# [Display Image from DataFrame](https://www.kaggle.com/code/stassl/displaying-inline-images-in-pandas-dataframe)
#
# [OpenCV - Working with Images](https://youtu.be/qCR2Weh64h4?t=77)
#
# [Image Manipulation with Pillow](https://www.youtube.com/watch?v=6Qs3wObeWwc)
#
# [Image Processing with Pillow](https://www.youtube.com/watch?v=NSHsaG2a4WU)
#
# [Show Images in Jupyter Notebook](https://saturncloud.io/blog/how-to-show-images-in-jupyter-notebook/)
#
# [matplotlib - Image Tutorial](https://matplotlib.org/stable/tutorials/images.html)

# %%
# %pip install pillow

from PIL import Image
beagle = Image.open("dog_images/beagle.jpg")
beagle.save("dog_images/beagle.png")
boxer = Image.open("dog_images/boxer.jpg")
shepherd = Image.open("dog_images/shepherd.jpg")

beagle
boxer
shepherd

img = beagle.copy()
beagle
img.show()

# beagle.show()
# boxer.show()
# shepherd.show()

# %%
# %pip install pillow

from PIL import Image
from IPython.display import display

beagle = Image.open("dog_images/beagle.jpg")
display(beagle)

boxer = Image.open("dog_images/boxer.jpg")
display(boxer)

shepherd = Image.open("dog_images/shepherd.jpg")
display(shepherd)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=326x360>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=360x297>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=333x500>

# %%
from PIL import Image

import matplotlib.pyplot as plt
import numpy as np

beagle = Image.open("dog_images/beagle.jpg")
img = np.asarray(beagle)
# print(repr(img))

plt.xticks([])
plt.yticks([])
temp = plt.imshow(beagle)       # storing image in a variable (temp) removes unwanted text output [<matplotlib.image.AxesImage at 0x1ccac2e5b90>]
