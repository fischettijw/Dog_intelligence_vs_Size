# %% [markdown]
# [Display Image from File](https://www.youtube.com/watch?v=WH5y0ZPP5lY&t=11s)
#
# [Display Image from DataFrame](https://www.kaggle.com/code/stassl/displaying-inline-images-in-pandas-dataframe)
#
# [Stanford Dogs Dataset - images](https://www.kaggle.com/datasets/jessicali9530/stanford-dogs-dataset)
#
# [OpenCV - Working with Images](https://youtu.be/qCR2Weh64h4?t=77)
#
# [Image Manipulation with Pillow](https://www.youtube.com/watch?v=6Qs3wObeWwc)
#
# [Image Processing with Pillow](https://www.youtube.com/watch?v=NSHsaG2a4WU)
#
# [Show Images in Jupyter Notebook](https://saturncloud.io/blog/how-to-show-images-in-jupyter-notebook/)
#
# [matplotlib - Image Tutorial](https://matplotlib.org/stable/tutorials/images.html)
#
# [Wikipedia: The Intelligence of Dogs](https://en.m.wikipedia.org/wiki/The_Intelligence_of_Dogs#cite_ref-ReferenceA_18-0)

# %%
# %pip install pillow

# from PIL import Image
# poodle = Image.open("dog_images\poodle.jpg")
# Border_Collie = Image.open("dog_images\Border_Collie.jpg")
# shepherd = Image.open("dog_images\German_Shepherd.jpg")

# poodle
# Border_Collie
# shepherd

# img = poodle.copy()
# poodle
# img.show()

# beagle.show()
# boxer.show()
# shepherd.show()

# %%
# %pip install pillow

from PIL import Image
from IPython.display import display

Poople = Image.open("dog_images\Poodle.jpg")
display(Poople)

Border_Collie = Image.open("dog_images\Border_Collie.jpg")
display(Border_Collie)

German_Shepherd = Image.open("dog_images\German_Shepherd.jpg")
display(German_Shepherd)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=440x291>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=440x360>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=440x366>

# %%
from PIL import Image

import matplotlib.pyplot as plt
import numpy as np

Border_Collie = Image.open("dog_images\Border_Collie.jpg")
img = np.asarray(Border_Collie)
# print(repr(img))

plt.xticks([])
plt.yticks([])
temp = plt.imshow(Border_Collie)       # storing image in a variable (temp) removes unwanted text output [<matplotlib.image.AxesImage at 0x1ccac2e5b90>]
